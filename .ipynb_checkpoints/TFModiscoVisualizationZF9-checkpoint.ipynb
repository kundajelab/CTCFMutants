# %% [markdown]
# This notebook is for visualizing the new TF-Modisco results for ZF9 from CTCF.

# %%
# Import necessary dependencies

# %matplotlib inline
from __future__ import division;
from __future__ import print_function;
import numpy as np
import modisco
import sys
print (sys.version)
import os
# Out:
# TF-MoDISco is using the TensorFlow backend.
# 2.7.15 |Anaconda custom (64-bit)| (default, Oct 10 2018, 21:32:13)
# [GCC 7.3.0]

# %% [markdown]
# Save and print the results.

# %%
import h5py
import modisco.util
reload(modisco.util)

from collections import Counter
from modisco.visualization import viz_sequence
reload(viz_sequence)
from matplotlib import pyplot as plt

import modisco.affinitymat.core
reload(modisco.affinitymat.core)
import modisco.cluster.phenograph.core
reload(modisco.cluster.phenograph.core)
import modisco.cluster.phenograph.cluster
reload(modisco.cluster.phenograph.cluster)
import modisco.cluster.core
reload(modisco.cluster.core)
import modisco.aggregator
reload(modisco.aggregator)

hdf5_results = h5py.File("CTCFZF9_actB_vsWT_1000bp_conv3LowFiltTop_TFModiscoResults.h5","r")

print("Metaclusters heatmap")
import seaborn as sns
activity_patterns = np.array(hdf5_results['metaclustering_results']['attribute_vectors'])[
                    np.array(
        [x[0] for x in sorted(
                enumerate(hdf5_results['metaclustering_results']['metacluster_indices']),
               key=lambda x: x[1])])]
sns.heatmap(activity_patterns, center=0)
plt.show()

metacluster_names = [
    x.decode("utf-8") for x in 
    list(hdf5_results["metaclustering_results"]
         ["all_metacluster_names"][:])]

all_patterns = []

for metacluster_name in metacluster_names:
    print(metacluster_name)
    metacluster_grp = (hdf5_results["metacluster_idx_to_submetacluster_results"]
                                   [metacluster_name])
    print("activity pattern:",metacluster_grp["activity_pattern"][:])
    all_pattern_names = [x.decode("utf-8") for x in 
                         list(metacluster_grp["seqlets_to_patterns_result"]
                                             ["patterns"]["all_pattern_names"][:])]
    if (len(all_pattern_names)==0):
        print("No motifs found for this activity pattern")
    for pattern_name in all_pattern_names:
        print(metacluster_name, pattern_name)
        all_patterns.append((metacluster_name, pattern_name))
        pattern = metacluster_grp["seqlets_to_patterns_result"]["patterns"][pattern_name]
        print("total seqlets:",len(pattern["seqlets_and_alnmts"]["seqlets"]))
        background = np.array([0.28, 0.21, 0.21, 0.28])
        print("Task 0 hypothetical scores:")
        viz_sequence.plot_weights(pattern["task0_hypothetical_contribs"]["fwd"])
        print("Task 0 actual importance scores:")
        viz_sequence.plot_weights(pattern["task0_contrib_scores"]["fwd"])
        viz_sequence.plot_weights(viz_sequence.ic_scale(np.array(pattern["sequence"]["fwd"]),
                                                        background=background)) 
        viz_sequence.plot_weights(viz_sequence.ic_scale(np.array(pattern["sequence"]["rev"]),
                                                        background=background)) 
        
hdf5_results.close()
# Out:
# Metaclusters heatmap
# metacluster_0
# activity pattern: [1]
# metacluster_0 pattern_0
# total seqlets: 1644
# Task 0 hypothetical scores:
# Task 0 actual importance scores:
# metacluster_0 pattern_1
# total seqlets: 678
# Task 0 hypothetical scores:
# Task 0 actual importance scores:
# metacluster_0 pattern_2
# total seqlets: 94
# Task 0 hypothetical scores:
# Task 0 actual importance scores:
# metacluster_0 pattern_3
# total seqlets: 75
# Task 0 hypothetical scores:
# Task 0 actual importance scores:
# metacluster_0 pattern_4
# total seqlets: 43
# Task 0 hypothetical scores:
# Task 0 actual importance scores:
# metacluster_0 pattern_5
# total seqlets: 66
# Task 0 hypothetical scores:
# Task 0 actual importance scores:
# metacluster_0 pattern_6
# total seqlets: 25
# Task 0 hypothetical scores:
# Task 0 actual importance scores:
# metacluster_1
# activity pattern: [-1]
# metacluster_1 pattern_0
# total seqlets: 608
# Task 0 hypothetical scores:
# Task 0 actual importance scores:
# metacluster_1 pattern_1
# total seqlets: 436
# Task 0 hypothetical scores:
# Task 0 actual importance scores:
# metacluster_1 pattern_2
# total seqlets: 429
# Task 0 hypothetical scores:
# Task 0 actual importance scores:
# metacluster_1 pattern_3
# total seqlets: 401
# Task 0 hypothetical scores:
# Task 0 actual importance scores:
# metacluster_1 pattern_4
# total seqlets: 194
# Task 0 hypothetical scores:
# Task 0 actual importance scores:
# metacluster_1 pattern_5
# total seqlets: 137
# Task 0 hypothetical scores:
# Task 0 actual importance scores:
# metacluster_1 pattern_6
# total seqlets: 63
# Task 0 hypothetical scores:
# Task 0 actual importance scores:

# %%
# Get the PFM with the most seqlets

hdf5_results = h5py.File("CTCFZF9_actB_vsWT_1000bp_conv3LowFiltTop_TFModiscoResults.h5","r")

activity_patterns = np.array(hdf5_results['metaclustering_results']['attribute_vectors'])[
                    np.array(
        [x[0] for x in sorted(
                enumerate(hdf5_results['metaclustering_results']['metacluster_indices']),
               key=lambda x: x[1])])]

metacluster_names = [
    x.decode("utf-8") for x in 
    list(hdf5_results["metaclustering_results"]
         ["all_metacluster_names"][:])]

all_patterns = []

for metacluster_name in metacluster_names:
    print(metacluster_name)
    metacluster_grp = (hdf5_results["metacluster_idx_to_submetacluster_results"]
                                   [metacluster_name])
    print("activity pattern:",metacluster_grp["activity_pattern"][:])
    all_pattern_names = [x.decode("utf-8") for x in 
                         list(metacluster_grp["seqlets_to_patterns_result"]
                                             ["patterns"]["all_pattern_names"][:])]
    if (len(all_pattern_names)==0):
        print("No motifs found for this activity pattern")
    if metacluster_name != "metacluster_0":
        continue
    pattern_name = all_pattern_names[0]
    print(metacluster_name, pattern_name)
    all_patterns.append((metacluster_name, pattern_name))
    pattern = metacluster_grp["seqlets_to_patterns_result"]["patterns"][pattern_name]
    print("total seqlets:",len(pattern["seqlets_and_alnmts"]["seqlets"]))
    background = np.array([0.28, 0.21, 0.21, 0.28])
    print("Task 0 hypothetical scores:")
    viz_sequence.plot_weights(pattern["task0_hypothetical_contribs"]["fwd"])
    viz_sequence.plot_weights(pattern["sequence"]["fwd"])
    print(np.array(pattern["task0_hypothetical_contribs"]["fwd"]))
    print(np.array(pattern["sequence"]["fwd"]))
        
hdf5_results.close()
# Out:
# metacluster_0
# activity pattern: [1]
# metacluster_0 pattern_0
# total seqlets: 1644
# Task 0 hypothetical scores:
# [[-0.00248802  0.00442836  0.00473563 -0.00418231]
#  [-0.00158991  0.00395664  0.00366358 -0.00394705]
#  [-0.00413413  0.00577264  0.00153928 -0.0043454 ]
#  [-0.007477    0.00549176  0.0070649  -0.01011809]
#  [-0.00841486  0.01312624  0.00418535 -0.005925  ]
#  [-0.00438517  0.00143254  0.01857045 -0.01464812]
#  [-0.01230339  0.00686815  0.00705885 -0.01955272]
#  [-0.00767997  0.02078646 -0.00505431 -0.00680712]
#  [ 0.004059    0.00476739  0.00200355 -0.01708147]
#  [-0.01163985  0.02533613 -0.01224879  0.02989495]
#  [-0.01994304  0.01753755  0.00471898 -0.02032843]
#  [-0.0279622  -0.02180913 -0.00901667  0.01172794]
#  [ 0.01270762 -0.00573572  0.01403302 -0.05147209]
#  [0.0310219  0.76277372 0.0176399  0.18856448]
#  [0.80109489 0.0553528  0.05291971 0.0906326 ]
#  [0.24574209 0.07785888 0.59184915 0.08454988]
#  [0.02615572 0.02554745 0.02737226 0.92092457]
#  [0.33272506 0.0663017  0.32238443 0.27858881]
#  [0.06690998 0.80839416 0.0377129  0.08698297]
#  [0.09245742 0.68491484 0.03163017 0.19099757]
#  [0.18430657 0.40997567 0.10218978 0.30352798]
#  [0.37469586 0.18187348 0.24635036 0.19708029]
#  [0.24148418 0.30839416 0.14476886 0.3053528 ]
#  [0.39659367 0.13564477 0.31021898 0.15754258]
#  [0.18734793 0.15571776 0.50121655 0.15571776]
#  [0.44647202 0.21776156 0.09184915 0.24391727]
#  [0.17822384 0.12104623 0.52615572 0.17457421]
#  [0.18491484 0.08759124 0.59854015 0.12895377]
#  [0.09367397 0.79318735 0.05961071 0.05352798]
#  [0.03892944 0.92396594 0.01581509 0.02128954]
#  [0.75425791 0.04379562 0.06995134 0.13199513]
#  [0.07055961 0.27737226 0.61313869 0.03892944]
#  [0.52128954 0.20985401 0.06995134 0.19890511]
#  [0.83333333 0.02554745 0.09124088 0.04987835]
#  [0.03284672 0.01824818 0.93004866 0.01885645]
#  [0.57055961 0.00973236 0.3959854  0.02372263]
#  [0.05961071 0.02128954 0.68552311 0.23357664]
#  [0.03892944 0.01824818 0.90815085 0.03467153]
#  [0.04562044 0.06021898 0.81934307 0.07481752]
#  [0.11678832 0.69829684 0.06265207 0.12226277]
#  [0.4580292  0.08759124 0.37956204 0.07481752]
#  [0.10097324 0.33029197 0.20498783 0.36374696]
#  [0.14233577 0.44829684 0.10705596 0.30231144]
#  [0.4689781  0.14963504 0.27068127 0.1107056 ]
#  [0.16666667 0.13807786 0.48905109 0.20620438]
#  [0.513382   0.1283455  0.18734793 0.17092457]]
# metacluster_1
# activity pattern: [-1]

# %%
# Get the PFM with the alternative spacing

hdf5_results = h5py.File("CTCFZF9_actB_vsWT_1000bp_conv3LowFiltTop_TFModiscoResults.h5","r")

activity_patterns = np.array(hdf5_results['metaclustering_results']['attribute_vectors'])[
                    np.array(
        [x[0] for x in sorted(
                enumerate(hdf5_results['metaclustering_results']['metacluster_indices']),
               key=lambda x: x[1])])]

metacluster_names = [
    x.decode("utf-8") for x in 
    list(hdf5_results["metaclustering_results"]
         ["all_metacluster_names"][:])]

all_patterns = []

for metacluster_name in metacluster_names:
    print(metacluster_name)
    metacluster_grp = (hdf5_results["metacluster_idx_to_submetacluster_results"]
                                   [metacluster_name])
    print("activity pattern:",metacluster_grp["activity_pattern"][:])
    all_pattern_names = [x.decode("utf-8") for x in 
                         list(metacluster_grp["seqlets_to_patterns_result"]
                                             ["patterns"]["all_pattern_names"][:])]
    if (len(all_pattern_names)==0):
        print("No motifs found for this activity pattern")
    if metacluster_name != "metacluster_0":
        continue
    pattern_name = all_pattern_names[1]
    print(metacluster_name, pattern_name)
    all_patterns.append((metacluster_name, pattern_name))
    pattern = metacluster_grp["seqlets_to_patterns_result"]["patterns"][pattern_name]
    print("total seqlets:",len(pattern["seqlets_and_alnmts"]["seqlets"]))
    background = np.array([0.28, 0.21, 0.21, 0.28])
    print("Task 0 hypothetical scores:")
    viz_sequence.plot_weights(pattern["task0_hypothetical_contribs"]["rev"])
    viz_sequence.plot_weights(pattern["sequence"]["rev"])
    print(np.array(pattern["task0_hypothetical_contribs"]["rev"]))
    print(np.array(pattern["sequence"]["rev"]))
        
hdf5_results.close()
# Out:
# metacluster_0
# activity pattern: [1]
# metacluster_0 pattern_1
# total seqlets: 678
# Task 0 hypothetical scores:
# [[-3.96986673e-03  3.97574937e-03  5.88509290e-03 -5.87620743e-03]
#  [-4.68491437e-03  6.25491391e-03  5.01352355e-03 -6.43597663e-03]
#  [-3.00365543e-03  4.07806257e-03  3.63286480e-03 -4.04427492e-03]
#  [-3.72995319e-03  5.58724855e-03  4.40523637e-03 -5.73473979e-03]
#  [-4.92679893e-03  1.09060369e-02  7.80628324e-03 -4.90155131e-03]
#  [-4.02460868e-03  6.73931170e-03  1.11827627e-02 -8.85066087e-03]
#  [-8.30570755e-03  4.70915081e-03  1.11868622e-02 -1.01815842e-02]
